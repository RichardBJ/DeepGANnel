# %%
import tensorflow as tf
import tensorflow_probability as tfp
from matplotlib import pyplot as plt
import warnings
import logging
import os
import os

import warnings
import logging
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
logging.getLogger("tensorflow").setLevel(logging.ERROR)

warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=UserWarning)
warnings.filterwarnings('ignore', message="Note the GPU implementation does not produce the same series as CPU implementation.")

# Define the transition matrix
transition_matrix = tf.constant([[0.8, 0.2], [0.3, 0.7]])  # Example transition matrix
tf.random.set_seed(1234)

# Define the transition function
# This function uses tf.gather to select the correct row of the transition matrix
transition_fn = lambda _, state: tfp.distributions.Categorical(
    probs=tf.gather(transition_matrix, state))  

# Define the initial state distribution
initial_distribution = tfp.distributions.Categorical(probs=[0.5, 0.5])


# Define the Markov chain
markov_chain = tfp.distributions.MarkovChain(
    initial_state_prior=initial_distribution,
    transition_fn=transition_fn,
    num_steps=1000  # Number of steps to simulate
)

# Sample from the Markov chain
samples = markov_chain.sample()

# Print the result
tf.print(samples)

# Plot the result
plt.plot(samples.numpy()[:100])  # Convert tensor to numpy array for plotting
plt.show()
# Out:
# [1 1 0 ... 1 1 0]

# %%
import tensorflow as tf
import tensorflow_probability as tfp
from matplotlib import pyplot as plt
import warnings
import logging
import os
import sys

# Attempt 1: Set TensorFlow logging level
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# Attempt 2: Set logging level for TensorFlow logger
logging.getLogger("tensorflow").setLevel(logging.ERROR)

# Attempt 3: Set TensorFlow logger level
tf.get_logger().setLevel('ERROR')

# Attempt 4: Redirect stderr (use with caution)
stderr = sys.stderr
sys.stderr = open(os.devnull, 'w')

# Your original code starts here
# Define the transition matrix
transition_matrix = tf.constant([[0.8, 0.2], [0.3, 0.7]])  # Example transition matrix
tf.random.set_seed(1234)

# Define the transition function
# This function uses tf.gather to select the correct row of the transition matrix
transition_fn = lambda _, state: tfp.distributions.Categorical(
    probs=tf.gather(transition_matrix, state))  

# Define the initial state distribution
initial_distribution = tfp.distributions.Categorical(probs=[0.5, 0.5])

# Define the Markov chain
markov_chain = tfp.distributions.MarkovChain(
    initial_state_prior=initial_distribution,
    transition_fn=transition_fn,
    num_steps=1000  # Number of steps to simulate
)

# Sample from the Markov chain
samples = markov_chain.sample()

# Print the result
tf.print(samples)

# Restore stderr
sys.stderr = stderr
# Out:
# 2024-08-30 10:18:50.838105: I metal_plugin/src/kernels/stateless_random_op.cc:282] Note the GPU implementation does not produce the same series as CPU implementation.
# 2024-08-30 10:18:50.947320: I metal_plugin/src/kernels/stateless_random_op.cc:282] Note the GPU implementation does not produce the same series as CPU implementation.
# 2024-08-30 10:18:50.957249: I metal_plugin/src/kernels/stateless_random_op.cc:282] Note the GPU implementation does not produce the same series as CPU implementation.
# 2024-08-30 10:18:50.962061: I metal_plugin/src/kernels/stateless_random_op.cc:282] Note the GPU implementation does not produce the same series as CPU implementation.
# 2024-08-30 10:18:50.965447: I metal_plugin/src/kernels/stateless_random_op.cc:282] Note the GPU implementation does not produce the same series as CPU implementation.
# ...

# %%
# Plot the result
plt.plot(samples.numpy()[:100])  # Convert tensor to numpy array for plotting
plt.show()
