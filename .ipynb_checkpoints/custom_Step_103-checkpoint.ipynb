# %%
#Runs successfully on MBP 2024 metal_102 conda environment.
import numpy as np
import torch
import torch.nn as nn
import pymc as pm
from pymc.util import get_value_vars_from_user_vars
import arviz as az
import pytensor.tensor as tt
from pytensor import scan
from tqdm import tqdm
import matplotlib.pyplot as plt
from IPython.display import clear_output
# Suppress PyTorch warnings
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'  # Use CPU instead of GPU
print(pm.__version__)
# Out:
# 5.12.0

# %%
import cProfile
import pstats

def profile_func(func):
    def wrapper(*args, **kwargs):
        profiler = cProfile.Profile()
        result = profiler.runcall(func, *args, **kwargs)
        stats = pstats.Stats(profiler).sort_stats('cumulative')
        stats.print_stats(20)  # Print top 20 time-consuming operations
        return result
    return wrapper

# %%
# Define constants
SIZE = 200
T=200
dt=0.1
NUM_SAMPLES = 100
EPOCHS = 1000
DEBUG = True

# %%
import pymc as pm
from pymc.step_methods import CompoundStep, Metropolis
import numpy as np
import pytensor.tensor as pt
import torch

class CustomGANStep(CompoundStep):
    def __init__(self, vars, discriminator, T=200, dt=0.1, debug=False):
        # Create a Metropolis step for each variable
        metropolis_steps = [Metropolis([var]) for var in vars]
        
        # Initialize CompoundStep with these Metropolis steps
        super().__init__(metropolis_steps)

        # Store additional information in a dictionary
        self.gan_info = {
            'discriminator': discriminator,
            'T': T,
            'dt': dt,
            'vars': vars,
            'var_names': [var.name for var in vars]
        }
        self.debug = debug
        if self.debug:
            print(f"Initialized CustomGANStep with variables: {self.gan_info['var_names']}")

    def step(self, point):
        # Get current values
        q = []
        for var in self.gan_info['vars']:
            if var.name in point:
                q.append(point[var.name])
            else:
                # Try to find a matching key (e.g., 'kc21_logodds__' for 'kc21')
                matching_key = next((k for k in point.keys() if k.startswith(var.name)), None)
                if matching_key:
                    q.append(point[matching_key])
                else:
                    raise KeyError(f"Cannot find a matching key for variable {var.name}")
        
        if self.debug:
            print(f"Current params: {q}")

        # Propose new values
        q_new = self.proposal(q)
        if self.debug:
            print(f"Proposed params: {q_new}")

        # Generate synthetic data
        synthetic_data_current = self.generate_synthetic_data(q)
        synthetic_data_proposed = self.generate_synthetic_data(q_new)

        # Get discriminator scores
        current_disc_score = self.get_discriminator_score(synthetic_data_current)
        proposed_disc_score = self.get_discriminator_score(synthetic_data_proposed)

        # Compute acceptance probability
        accept = self.compute_acceptance(point, q_new, current_disc_score, proposed_disc_score)

        # Ensure accept is a scalar float
        accept_prob = float(accept)

        if np.random.random() < accept_prob:
            for var, val in zip(self.gan_info['vars'], q_new):
                if var.name in point:
                    point[var.name] = np.atleast_1d(val)
                else:
                    matching_key = next(k for k in point.keys() if k.startswith(var.name))
                    point[matching_key] = np.atleast_1d(val)
        else:
            for var in self.gan_info['vars']:
                if var.name in point:
                    point[var.name] = np.atleast_1d(point[var.name])
                else:
                    matching_key = next(k for k in point.keys() if k.startswith(var.name))
                    point[matching_key] = np.atleast_1d(point[matching_key])

        # Return the new point and an empty stats dictionary
        return point, {}

    def proposal(self, q):
        return [val + np.random.normal(0, 0.1) for val in q]  # You might want to adjust the step size (0.1)

    def compute_acceptance(self, current_point, proposed_values, current_disc_score, proposed_disc_score):
        current_logp = self.logp(current_point)
        
        proposed_point = current_point.copy()
        for var, val in zip(self.gan_info['vars'], proposed_values):
            if var.name in proposed_point:
                proposed_point[var.name] = val
            else:
                matching_key = next(k for k in proposed_point.keys() if k.startswith(var.name))
                proposed_point[matching_key] = val
        
        proposed_logp = self.logp(proposed_point)

        # Metropolis-Hastings acceptance ratio
        ratio = pt.exp(proposed_logp - current_logp)

        # Incorporate discriminator scores
        ratio = ratio * np.exp(proposed_disc_score - current_disc_score)

        # Ensure ratio is a scalar
        ratio = pt.as_tensor_variable(ratio).eval()

        return min(1, ratio)

    def generate_synthetic_data(self, params):
        if self.debug:
            print(f"Params passed to generate_synthetic_data: {params}")
        params = [float(p) for p in params]  # Convert to float
        return pymc_sim_channel(params, self.gan_info['T'], self.gan_info['dt'], source="torch")

    def get_discriminator_score(self, data):
        if isinstance(data, torch.Tensor):
            data_tensor = data.clone().detach().float().unsqueeze(0)
        else:
            data_tensor = torch.tensor(data).float().unsqueeze(0)
        with torch.no_grad():
            score = self.gan_info['discriminator'](data_tensor).item()
        return score

    def logp(self, point):
        # Calculate the log probability for each variable separately
        logp_sum = 0
        for var in self.gan_info['vars']:
            if var.name in point:
                logp_sum += pm.logp(var, point[var.name]).sum()
            else:
                matching_key = next(k for k in point.keys() if k.startswith(var.name))
                logp_sum += pm.logp(var, point[matching_key]).sum()
        return logp_sum

# %%
# Define the discriminator model
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Conv1d(2, 64, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(),
            nn.Conv1d(64, 128, kernel_size=5, stride=2, padding=2),
            nn.LeakyReLU(),
            nn.Flatten(),
            nn.Linear(128 * (SIZE // 4), 1)
        )

    def forward(self, x):
        return self.model(x.permute(0, 2, 1))

# %%
# Loss function for the discriminator
def discriminator_loss(real_output, fake_output):
    real_loss = nn.BCEWithLogitsLoss()(real_output, torch.ones_like(real_output))
    fake_loss = nn.BCEWithLogitsLoss()(fake_output, torch.zeros_like(fake_output))
    return real_loss + fake_loss

# %%
# Create and compile the discriminator
discriminator = Discriminator()
discriminator_optimizer = torch.optim.Adam(discriminator.parameters(), lr=1e-4)

# %%
import pytensor.tensor as tt
from pytensor.scan import scan
from pytensor.tensor.random.utils import RandomStream
import torch
import numpy as np

def pymc_sim_channel(params, T, dt, source="torch"):
    kc12, kc21, Fnoise, scale, offset, kco1, koc2, ko12, ko21 = params
    eps = 1e-10  # Small constant to avoid zero probabilities
    if source == "pymc":
        zero = tt.constant(0.0)
        one = tt.constant(1.0)
        
        # Convert parameters to PyTensor tensors
        """
        kc12, kc21, kco1, koc2, ko12, ko21, Fnoise, scale = map(tt.as_tensor_variable, 
                                                                        [kc12, kc21, kco1, koc2, ko12, ko21, Fnoise, scale])

        """
        kc12, kc21, kco1, koc2, ko12, ko21, Fnoise, scale = map(lambda x: tt.maximum(tt.as_tensor_variable(x), eps), 
                                                                [kc12, kc21, kco1, koc2, ko12, ko21, Fnoise, scale])
        # Create transition matrix
        row1 = tt.stack([1-kc12, kc12, zero, zero])
        row2 = tt.stack([kc21, 1-kc21-kco1, kco1, zero])
        row3 = tt.stack([zero, koc2, 1-koc2-ko12, ko12])
        row4 = tt.stack([zero, zero, ko21, 1-ko21])
        transition_matrix = tt.stack([row1, row2, row3, row4])

        transition_matrix = tt.maximum(transition_matrix, eps)
        row_sums = transition_matrix.sum(axis=1, keepdims=True)
        transition_matrix = transition_matrix / row_sums
        
        # Create a RandomStream for managing the RNG
        srng = RandomStream()
        
        # Generate random initial state
        initial_state = srng.categorical(tt.ones(4) / 4, size=(1,))
        
        def step(state, transition_probs):
            new_state = srng.categorical(transition_probs[state[0]], size=(1,))
            return new_state
        
        states, _ = scan(
            fn=step,
            outputs_info=initial_state,
            non_sequences=transition_matrix,
            n_steps=SIZE-1
        )
        
        states = tt.concatenate([initial_state, states.flatten()])
        
        # Convert states to channels
        channels = tt.switch(states < 2, zero, one)
        
        # Generate noise
        noise = srng.normal(0, Fnoise, size=(SIZE,))
        
        # Combine channels and noise
        result = tt.stack([channels, channels * scale + offset + noise], axis=-1)
        
        # Return the PyTensor variable directly
        return result


    else:
        # Convert to PyTorch tensors
        kc12, kc21, kco1, koc2, ko12, ko21, Fnoise, scale = map(lambda x: torch.tensor(max(x, eps)), 
                                                                        [kc12, kc21, kco1, koc2, ko12, ko21, Fnoise, scale])
        
        # Create transition matrix
        row1 = torch.tensor([1-kc12, kc12, 0, 0])
        row2 = torch.tensor([kc21, 1-kc21-kco1, kco1, 0])
        row3 = torch.tensor([0, koc2, 1-koc2-ko12, ko12])
        row4 = torch.tensor([0, 0, ko21, 1-ko21])
                
        transition_matrix = torch.stack([row1, row2, row3, row4])
        
        # Ensure non-negative values and add small constant
        transition_matrix = torch.clamp(transition_matrix, min=eps)
        
        # Normalize rows to sum to 1
        row_sums = transition_matrix.sum(dim=1, keepdim=True)
        transition_matrix = transition_matrix / row_sums
        
        def transition_fn(state):
            probs = transition_matrix[state]
            return torch.distributions.Categorical(probs=probs).sample()
        
        initial_probs = torch.ones(4) / 4  # Equal probability for all initial states
        initial_distribution = torch.distributions.Categorical(probs=initial_probs)
        
        states = [initial_distribution.sample().item()]
        
        for _ in range(SIZE - 1):
            states.append(transition_fn(states[-1]).item())
        
        channels = torch.tensor(states)
        channels = torch.where(channels < 2, torch.zeros_like(channels), torch.ones_like(channels))
        noise = torch.normal(0, Fnoise, (SIZE,))
        
        res = torch.stack([channels, channels * scale + offset + noise], axis=-1)
        return res

# %%
kc12=0.1
kc21=2
Fnoise=0.01
scale=0.25
offset=-0.4
kco1=0.5
kco2=0.25
ko12=1
ko21=2 
orig_params=[kc12,kc21,Fnoise,scale, offset,kco1,kco2,ko12,ko21]
plt.figure(figsize=(12, 6))
plt.plot(pymc_sim_channel(orig_params, T, dt))
plt.title('torch sim Channel Data')
# Out:
# Text(0.5, 1.0, 'torch sim Channel Data')

# %%
real_data = torch.stack([pymc_sim_channel(orig_params, T, dt) for _ in range(NUM_SAMPLES)], dim=0)

# %%
import pymc as pm
import pytensor.tensor as tt
import numpy as np
import arviz as az
import matplotlib.pyplot as plt

def create_model(T, dt, NUM_SAMPLES):
    with pm.Model() as model:
        # Priors for parameters (using transformed distributions to ensure valid ranges)
        kc21 = pm.Beta('kc21', alpha=2, beta=5)
        kc12 = pm.Beta('kc12', alpha=2, beta=5)
        kco1 = pm.Beta('kco1', alpha=2, beta=5)
        koc2 = pm.Beta('koc2', alpha=2, beta=5)
        ko12 = pm.Beta('ko12', alpha=2, beta=5)
        ko21 = pm.Beta('ko21', alpha=2, beta=5)
        Fnoise = pm.HalfNormal('Fnoise', sigma=1)
        scale = pm.HalfNormal('scale', sigma=1)
        offset = pm.Normal('offset', mu=0, sigma=1)

        # Placeholder for discriminator probabilities
        discriminator_probs = pm.MutableData('discriminator_probs', np.ones(NUM_SAMPLES) * 0.5)

        # Add a small epsilon to avoid log(0) or log(1)
        epsilon = 1e-7
        safe_probs = tt.clip(discriminator_probs, epsilon, 1 - epsilon)

        # Likelihood based on discriminator probabilities
        likelihood = pm.Potential('likelihood', tt.sum(tt.log(safe_probs)))

        # Debugging information
        if DEBUG:
            print("Model structure:")
            for v in model.named_vars.values():
                print(f"{v.name}: {type(v).__name__}")
                if hasattr(v, 'distribution'):
                    print(f"  Distribution: {type(v.distribution).__name__}")
                elif hasattr(v, 'tag'):
                    print(f"  Potential")
                else:
                    print(f"  Type: {type(v)}")

        print("\nRandom draw from prior:")
        prior_predictive = pm.sample_prior_predictive(samples=1000)
        for var_name, value in prior_predictive.prior.items():
            if var_name != 'discriminator_probs':
                print(f"{var_name}: mean = {value.mean().item():.4f}, std = {value.std().item():.4f}")

        print("\nPrior distributions:")
        fig, axes = plt.subplots(3, 3, figsize=(15, 15))
        axes = axes.flatten()
        for i, (var_name, value) in enumerate(prior_predictive.prior.items()):
            if var_name != 'discriminator_probs':
                az.plot_dist(value, ax=axes[i], label=var_name)
                axes[i].set_title(var_name)
                axes[i].legend()
        plt.tight_layout()
        plt.show()

    return model

# Usage
model = create_model(T, dt, NUM_SAMPLES)
print("\nModel created successfully!")
# Out:
# /var/folders/_n/b_grcm9j7pd5hrdkdnkl728m0000gn/T/ipykernel_69421/2441911285.py:43: UserWarning: The effect of Potentials on other parameters is ignored during prior predictive sampling. This is likely to lead to invalid or biased predictive samples.
#   prior_predictive = pm.sample_prior_predictive(samples=1000)
# Sampling: [Fnoise, kc12, kc21, kco1, ko12, ko21, koc2, offset, scale]
# Model structure:
# kc21: TensorVariable
#   Potential
# kc12: TensorVariable
#   Potential
# kco1: TensorVariable
#   Potential
# koc2: TensorVariable
#   Potential
# ko12: TensorVariable
#   Potential
# ko21: TensorVariable
#   Potential
# Fnoise: TensorVariable
#   Potential
# scale: TensorVariable
#   Potential
# offset: TensorVariable
#   Potential
# discriminator_probs: TensorSharedVariable
#   Potential
# likelihood: TensorVariable
#   Potential
#
# Random draw from prior:
# kc12: mean = 0.2833, std = 0.1562
# offset: mean = -0.0101, std = 1.0078
# ko12: mean = 0.2879, std = 0.1678
# ko21: mean = 0.2778, std = 0.1570
# scale: mean = 0.8009, std = 0.6025
# kco1: mean = 0.2751, std = 0.1621
# Fnoise: mean = 0.7840, std = 0.5967
# koc2: mean = 0.2793, std = 0.1567
# kc21: mean = 0.2819, std = 0.1600
#
# Prior distributions:
# Model created successfully!

# %%
def generate_synthetic_data(inference_data, num_samples, T, dt):
    # Extract parameters from the InferenceData object
    params = {var: inference_data.prior[var].values.flatten() for var in inference_data.prior.data_vars}
    
    synthetic_data = []
    for i in range(num_samples):
        # Randomly select a set of parameters
        sample_params = [np.random.choice(params[var]) for var in ['kc12', 'kc21', 'Fnoise', 'scale', 'offset', 'kco1', 'koc2', 'ko12', 'ko21']]
        # Generate a single synthetic data sample
        sample = pymc_sim_channel(sample_params, T, dt, source="torch")
        
        synthetic_data.append(sample)
    
    # Stack all samples into a single tensor
    return torch.stack(synthetic_data).float()

# %%
def custom_prior_predictive(model, num_samples, discriminator, T, dt):
    with model:
        # Sample from priors
        prior_samples = pm.sample_prior_predictive(samples=num_samples)
    
    # Extract parameter values from prior_samples
    param_values = {}
    for var in model.free_RVs:
        if var.name in prior_samples.prior:
            values = prior_samples.prior[var.name].values
            if values.ndim > 1:
                param_values[var.name] = values.reshape(num_samples, -1)
            else:
                param_values[var.name] = values.reshape(-1, 1)
        else:
            print(f"Warning: {var.name} not found in prior samples. Using random values.")
            param_values[var.name] = np.random.uniform(0, 1, (num_samples, 1))
    
    # Generate synthetic data
    synthetic_data = []
    for i in range(num_samples):
        sample_params = [param_values[var.name][i].flatten()[0] for var in model.free_RVs]
        sample = pymc_sim_channel(sample_params, T, dt, source="torch")
        synthetic_data.append(sample)
    
    synthetic_data = torch.stack(synthetic_data).float()
    
    # Get discriminator probabilities
    with torch.no_grad():
        disc_probs = torch.sigmoid(discriminator(synthetic_data)).numpy()
    
    # Adjust samples based on discriminator probabilities
    adjusted_samples = {}
    for var in model.free_RVs:
        adjusted_samples[var.name] = param_values[var.name] * disc_probs.reshape(-1, 1)
    
    return adjusted_samples

# Usage
prior_predictive = custom_prior_predictive(model, NUM_SAMPLES, discriminator, T, dt)
# Out:
# /var/folders/_n/b_grcm9j7pd5hrdkdnkl728m0000gn/T/ipykernel_69421/3717247554.py:4: UserWarning: The effect of Potentials on other parameters is ignored during prior predictive sampling. This is likely to lead to invalid or biased predictive samples.
#   prior_samples = pm.sample_prior_predictive(samples=num_samples)
# Sampling: [Fnoise, kc12, kc21, kco1, ko12, ko21, koc2, offset, scale]

# %%
class StepSkipException(Exception):
    pass


traces = []

def print_error(section, e):
    print(f"Error in {section}: {str(e)}")
    print(f"Traceback for {section}:")
    import traceback
    print(traceback.format_exc())

@profile_func
def train(epoch):
    try:
        # Generate synthetic data using current model state
        prior_predictive = pm.sample_prior_predictive(samples=NUM_SAMPLES)
        synthetic_data = generate_synthetic_data(prior_predictive, NUM_SAMPLES, T, dt)
    except Exception as e:
        print_error("synthetic data generation", e)
        raise StepSkipException(f"Error in {step} step: {str(e)}")
    
    try:
        # Train discriminator
        real_output = discriminator(real_data)
        fake_output = discriminator(synthetic_data)
        disc_loss = discriminator_loss(real_output, fake_output)
        discriminator_optimizer.zero_grad()
        disc_loss.backward()
        
        discriminator_optimizer.step()
        print(f"Discriminator Loss: {disc_loss.item()}")
    except Exception as e:
        print_error("discriminator training", e)
        raise StepSkipException(f"Error in {step} step: {str(e)}")

    if epoch < 0:
        trace = pm.sample(5000, chains=4, 
                          tune=100, cores=16, return_inferencedata=True)
        traces.append(trace)
    else:        
        try:
            # Perform MCMC with custom step method
            custom_step = CustomGANStep(vars=model.free_RVs, discriminator=discriminator, T=T, dt=dt, debug=DEBUG)
            print("Starting MCMC sampling with CustomGANStep")
            trace = pm.sample(50, step=custom_step, chains=2, 
                  tune=25, cores=2, return_inferencedata=True)
            traces.append(trace)
        except Exception as e:
            print_error("MCMC sampling", e)
            raise StepSkipException(f"Error in {step} step: {str(e)}")
        
    try:
        # Print progress
        if len(traces) > 1:
            combined_trace = az.concat(traces, dim="chain")
        else:
            combined_trace = traces[0]
        clear_output(wait=True)
        summary = az.summary(combined_trace)
        print(summary)
    except Exception as e:
        print_error("summary generation", e)
        raise StepSkipException(f"Error in {step} step: {str(e)}")
    


with model:
    print(f"Model variables: {[var.name for var in model.free_RVs]}")
    
    for epoch in tqdm(range(EPOCHS)):
        print(f"\nEpoch {epoch+1}/{EPOCHS}")
        train(epoch)
        
        # Uncomment the following line if you want to clear output in a Jupyter notebook
        # clear_output(wait=True)

# After training, analyze the results
try:
    if len(traces) > 1:
        final_trace = az.concat(traces, dim="chain")
    else:
        final_trace = traces[0]
    az.plot_trace(final_trace)
    plt.show()
except Exception as e:
    print_error("plotting traces", e)
# Out:
# Model variables: ['kc21', 'kc12', 'kco1', 'koc2', 'ko12', 'ko21', 'Fnoise', 'scale', 'offset']
#   0%|                                                                                                                          | 0/1000 [00:00<?, ?it/s]/var/folders/_n/b_grcm9j7pd5hrdkdnkl728m0000gn/T/ipykernel_69421/4216879396.py:17: UserWarning: The effect of Potentials on other parameters is ignored during prior predictive sampling. This is likely to lead to invalid or biased predictive samples.
#   prior_predictive = pm.sample_prior_predictive(samples=NUM_SAMPLES)
# Sampling: [Fnoise, kc12, kc21, kco1, ko12, ko21, koc2, offset, scale]
# Epoch 1/1000
# Discriminator Loss: 1.2997779846191406
# Only 50 samples per chain. Reliable r-hat and ESS diagnostics require longer chains for accurate estimate.
# Initialized CustomGANStep with variables: ['kc21', 'kc12', 'kco1', 'koc2', 'ko12', 'ko21', 'Fnoise', 'scale', 'offset']
# Starting MCMC sampling with CustomGANStep
# Multiprocess sampling (2 chains in 2 jobs)
# CompoundStep
# >Metropolis: [kc21]
# >Metropolis: [kc12]
# >Metropolis: [kco1]
# >Metropolis: [koc2]
# >Metropolis: [ko12]
# >Metropolis: [ko21]
# >Metropolis: [Fnoise]
# >Metropolis: [scale]
# >Metropolis: [offset]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='69' class='' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       46.00% [69/150 12:46&lt;14:59 Sampling 2 chains, 0 divergences]
#     </div>
# Current params: [array(-0.91629073), array(-0.91629073), array(-0.91629073), array(-0.91629073), array(-0.91629073), array(-0.91629073), array(0.), array(0.), array(0.)]
# Proposed params: [-1.0863553780354502, -1.0488090494394493, -0.9792552235821093, -0.8471800634046931, -1.0069552393451722, -0.894247872555905, -0.17426763022190658, 0.25792047050719913, -0.06191142040075398]
# Current params: [array(-0.91629073), array(-0.91629073), array(-0.91629073), array(-0.91629073), array(-0.91629073), array(-0.91629073), array(0.), array(0.), array(0.)]
# Params passed to generate_synthetic_data: [array(-0.91629073), array(-0.91629073), array(-0.91629073), array(-0.91629073), array(-0.91629073), array(-0.91629073), array(0.), array(0.), array(0.)]Proposed params: [-0.9231165133233808, -0.9124663974630084, -0.837750222955377, -0.9379825510324449, -1.03653857192666, -0.7804895230415517, -0.1885500656748735, 0.01332756766071357, 0.0336121020274986]
#
# Params passed to generate_synthetic_data: [array(-0.91629073), array(-0.91629073), array(-0.91629073), array(-0.91629073), array(-0.91629073), array(-0.91629073), array(0.), array(0.), array(0.)]
# Params passed to generate_synthetic_data: [-1.0863553780354502, -1.0488090494394493, -0.9792552235821093, -0.8471800634046931, -1.0069552393451722, -0.894247872555905, -0.17426763022190658, 0.25792047050719913, -0.06191142040075398]
# Params passed to generate_synthetic_data: [-0.9231165133233808, -0.9124663974630084, -0.837750222955377, -0.9379825510324449, -1.03653857192666, -0.7804895230415517, -0.1885500656748735, 0.01332756766071357, 0.0336121020274986]
# Current params: [array([-1.08635538]), array([-1.04880905]), array([-0.97925522]), array([-0.84718006]), array([-1.00695524]), array([-0.89424787]), array([-0.17426763]), array([0.25792047]), array([-0.06191142])]
# Proposed params: [array([-1.10097826]), array([-1.08193441]), array([-1.02484729]), array([-0.92754775]), array([-1.08529083]), array([-0.98654507]), array([-0.21139879]), array([0.29809752]), array([0.02779977])]
# Params passed to generate_synthetic_data: [array([-1.08635538]), array([-1.04880905]), array([-0.97925522]), array([-0.84718006]), array([-1.00695524]), array([-0.89424787]), array([-0.17426763]), array([0.25792047]), array([-0.06191142])]
# Params passed to generate_synthetic_data: [array([-1.10097826]), array([-1.08193441]), array([-1.02484729]), array([-0.92754775]), array([-1.08529083]), array([-0.98654507]), array([-0.21139879]), array([0.29809752]), array([0.02779977])]
# Current params: [array([-0.92311651]), array([-0.9124664]), array([-0.83775022]), array([-0.93798255]), array([-1.03653857]), array([-0.78048952]), array([-0.18855007]), array([0.01332757]), array([0.0336121])]
# Proposed params: [array([-1.0886406]), array([-0.89975562]), array([-0.91777576]), array([-0.93477607]), array([-0.76688568]), array([-0.75346959]), array([-0.02835176]), array([-0.05488383]), array([0.16082316])]
# Params passed to generate_synthetic_data: [array([-0.92311651]), array([-0.9124664]), array([-0.83775022]), array([-0.93798255]), array([-1.03653857]), array([-0.78048952]), array([-0.18855007]), array([0.01332757]), array([0.0336121])]
# Params passed to generate_synthetic_data: [array([-1.0886406]), array([-0.89975562]), array([-0.91777576]), array([-0.93477607]), array([-0.76688568]), array([-0.75346959]), array([-0.02835176]), array([-0.05488383]), array([0.16082316])]
# Current params: [array([-1.0886406]), array([-0.89975562]), array([-0.91777576]), array([-0.93477607]), array([-0.76688568]), array([-0.75346959]), array([-0.02835176]), array([-0.05488383]), array([0.16082316])]
# Proposed params: [array([-1.17512502]), array([-0.73286907]), array([-0.94726795]), array([-0.82284616]), array([-0.60623441]), array([-0.58122736]), array([-0.1006981]), array([-0.18255085]), array([0.05779149])]
# Params passed to generate_synthetic_data: [array([-1.0886406]), array([-0.89975562]), array([-0.91777576]), array([-0.93477607]), array([-0.76688568]), array([-0.75346959]), array([-0.02835176]), array([-0.05488383]), array([0.16082316])]
# Params passed to generate_synthetic_data: [array([-1.17512502]), array([-0.73286907]), array([-0.94726795]), array([-0.82284616]), array([-0.60623441]), array([-0.58122736]), array([-0.1006981]), array([-0.18255085]), array([0.05779149])]
# Current params: [array([-1.10097826]), array([-1.08193441]), array([-1.02484729]), array([-0.92754775]), array([-1.08529083]), array([-0.98654507]), array([-0.21139879]), array([0.29809752]), array([0.02779977])]
# Proposed params: [array([-1.04240198]), array([-0.97260181]), array([-1.03656953]), array([-1.03606811]), array([-1.05630158]), array([-0.91468732]), array([-0.23921309]), array([0.34437424]), array([0.01268864])]
# Params passed to generate_synthetic_data: [array([-1.10097826]), array([-1.08193441]), array([-1.02484729]), array([-0.92754775]), array([-1.08529083]), array([-0.98654507]), array([-0.21139879]), array([0.29809752]), array([0.02779977])]
# Params passed to generate_synthetic_data: [array([-1.04240198]), array([-0.97260181]), array([-1.03656953]), array([-1.03606811]), array([-1.05630158]), array([-0.91468732]), array([-0.23921309]), array([0.34437424]), array([0.01268864])]
# Current params: [array([-1.17512502]), array([-0.73286907]), array([-0.94726795]), array([-0.82284616]), array([-0.60623441]), array([-0.58122736]), array([-0.1006981]), array([-0.18255085]), array([0.05779149])]
# Proposed params: [array([-1.10107092]), array([-0.79882989]), array([-0.71367104]), array([-0.95199485]), array([-0.61384023]), array([-0.67343334]), array([-0.05676794]), array([-0.03845879]), array([0.09808854])]
# Params passed to generate_synthetic_data: [array([-1.17512502]), array([-0.73286907]), array([-0.94726795]), array([-0.82284616]), array([-0.60623441]), array([-0.58122736]), array([-0.1006981]), array([-0.18255085]), array([0.05779149])]
# Params passed to generate_synthetic_data: [array([-1.10107092]), array([-0.79882989]), array([-0.71367104]), array([-0.95199485]), array([-0.61384023]), array([-0.67343334]), array([-0.05676794]), array([-0.03845879]), array([0.09808854])]
# Current params: [array([-1.04240198]), array([-0.97260181]), array([-1.03656953]), array([-1.03606811]), array([-1.05630158]), array([-0.91468732]), array([-0.23921309]), array([0.34437424]), array([0.01268864])]
# Proposed params: [array([-1.03057923]), array([-0.83651298]), array([-0.92757892]), array([-1.02455069]), array([-1.08119547]), array([-0.7064994]), array([-0.35046948]), array([0.22699286]), array([-0.10579321])]
# Params passed to generate_synthetic_data: [array([-1.04240198]), array([-0.97260181]), array([-1.03656953]), array([-1.03606811]), array([-1.05630158]), array([-0.91468732]), array([-0.23921309]), array([0.34437424]), array([0.01268864])]
# Params passed to generate_synthetic_data: [array([-1.03057923]), array([-0.83651298]), array([-0.92757892]), array([-1.02455069]), array([-1.08119547]), array([-0.7064994]), array([-0.35046948]), array([0.22699286]), array([-0.10579321])]
# Current params: [array([-1.03057923]), array([-0.83651298]), array([-0.92757892]), array([-1.02455069]), array([-1.08119547]), array([-0.7064994]), array([-0.35046948]), array([0.22699286]), array([-0.10579321])]
# Proposed params: [array([-0.98283601]), array([-0.75315659]), array([-0.87758129]), array([-1.02386471]), array([-1.08949454]), array([-0.77126366]), array([-0.54302514]), array([0.27752664]), array([-0.17209442])]
# Params passed to generate_synthetic_data: [array([-1.03057923]), array([-0.83651298]), array([-0.92757892]), array([-1.02455069]), array([-1.08119547]), array([-0.7064994]), array([-0.35046948]), array([0.22699286]), array([-0.10579321])]
# Params passed to generate_synthetic_data: [array([-0.98283601]), array([-0.75315659]), array([-0.87758129]), array([-1.02386471]), array([-1.08949454]), array([-0.77126366]), array([-0.54302514]), array([0.27752664]), array([-0.17209442])]
# Current params: [array([-1.10107092]), array([-0.79882989]), array([-0.71367104]), array([-0.95199485]), array([-0.61384023]), array([-0.67343334]), array([-0.05676794]), array([-0.03845879]), array([0.09808854])]
# Proposed params: [array([-1.07727112]), array([-0.69790699]), array([-0.75561032]), array([-1.00442939]), array([-0.48420169]), array([-0.64123412]), array([0.02968265]), array([-0.08702557]), array([0.06586106])]
# Params passed to generate_synthetic_data: [array([-1.10107092]), array([-0.79882989]), array([-0.71367104]), array([-0.95199485]), array([-0.61384023]), array([-0.67343334]), array([-0.05676794]), array([-0.03845879]), array([0.09808854])]
# Params passed to generate_synthetic_data: [array([-1.07727112]), array([-0.69790699]), array([-0.75561032]), array([-1.00442939]), array([-0.48420169]), array([-0.64123412]), array([0.02968265]), array([-0.08702557]), array([0.06586106])]
# Current params: [array([-1.07727112]), array([-0.69790699]), array([-0.75561032]), array([-1.00442939]), array([-0.48420169]), array([-0.64123412]), array([0.02968265]), array([-0.08702557]), array([0.06586106])]
# Proposed params: [array([-1.27718808]), array([-0.68842902]), array([-0.84552956]), array([-1.08858635]), array([-0.53622637]), array([-0.42962285]), array([0.01206706]), array([-0.23144982]), array([0.10531449])]
# Params passed to generate_synthetic_data: [array([-1.07727112]), array([-0.69790699]), array([-0.75561032]), array([-1.00442939]), array([-0.48420169]), array([-0.64123412]), array([0.02968265]), array([-0.08702557]), array([0.06586106])]
# Params passed to generate_synthetic_data: [array([-1.27718808]), array([-0.68842902]), array([-0.84552956]), array([-1.08858635]), array([-0.53622637]), array([-0.42962285]), array([0.01206706]), array([-0.23144982]), array([0.10531449])]
# Current params: [array([-0.98283601]), array([-0.75315659]), array([-0.87758129]), array([-1.02386471]), array([-1.08949454]), array([-0.77126366]), array([-0.54302514]), array([0.27752664]), array([-0.17209442])]
# Proposed params: [array([-1.04845313]), array([-0.81306824]), array([-1.0283473]), array([-1.12944369]), array([-1.12585132]), array([-0.73748029]), array([-0.55905381]), array([0.27533864]), array([-0.00707111])]
# Params passed to generate_synthetic_data: [array([-0.98283601]), array([-0.75315659]), array([-0.87758129]), array([-1.02386471]), array([-1.08949454]), array([-0.77126366]), array([-0.54302514]), array([0.27752664]), array([-0.17209442])]
# Params passed to generate_synthetic_data: [array([-1.04845313]), array([-0.81306824]), array([-1.0283473]), array([-1.12944369]), array([-1.12585132]), array([-0.73748029]), array([-0.55905381]), array([0.27533864]), array([-0.00707111])]
# Current params: [array([-1.27718808]), array([-0.68842902]), array([-0.84552956]), array([-1.08858635]), array([-0.53622637]), array([-0.42962285]), array([0.01206706]), array([-0.23144982]), array([0.10531449])]
# Proposed params: [array([-1.22652417]), array([-0.84702863]), array([-0.76947794]), array([-1.0280413]), array([-0.33783442]), array([-0.40956792]), array([-0.08019755]), array([-0.30659068]), array([0.12954913])]
# Params passed to generate_synthetic_data: [array([-1.27718808]), array([-0.68842902]), array([-0.84552956]), array([-1.08858635]), array([-0.53622637]), array([-0.42962285]), array([0.01206706]), array([-0.23144982]), array([0.10531449])]
# Params passed to generate_synthetic_data: [array([-1.22652417]), array([-0.84702863]), array([-0.76947794]), array([-1.0280413]), array([-0.33783442]), array([-0.40956792]), array([-0.08019755]), array([-0.30659068]), array([0.12954913])]
# Current params: [array([-1.04845313]), array([-0.81306824]), array([-1.0283473]), array([-1.12944369]), array([-1.12585132]), array([-0.73748029]), array([-0.55905381]), array([0.27533864]), array([-0.00707111])]
# Proposed params: [array([-1.10729454]), array([-0.79741429]), array([-1.03573647]), array([-1.08271846]), array([-1.05514026]), array([-0.6419704]), array([-0.45379012]), array([0.3306534]), array([-0.10989084])]
# Params passed to generate_synthetic_data: [array([-1.04845313]), array([-0.81306824]), array([-1.0283473]), array([-1.12944369]), array([-1.12585132]), array([-0.73748029]), array([-0.55905381]), array([0.27533864]), array([-0.00707111])]
# Params passed to generate_synthetic_data: [array([-1.10729454]), array([-0.79741429]), array([-1.03573647]), array([-1.08271846]), array([-1.05514026]), array([-0.6419704]), array([-0.45379012]), array([0.3306534]), array([-0.10989084])]
# Current params: [array([-1.22652417]), array([-0.84702863]), array([-0.76947794]), array([-1.0280413]), array([-0.33783442]), array([-0.40956792]), array([-0.08019755]), array([-0.30659068]), array([0.12954913])]
# Proposed params: [array([-1.39503015]), array([-0.86806963]), array([-0.6936365]), array([-1.10637413]), array([-0.32834432]), array([-0.38927684]), array([-0.0648041]), array([-0.34764988]), array([0.18549315])]
# Params passed to generate_synthetic_data: [array([-1.22652417]), array([-0.84702863]), array([-0.76947794]), array([-1.0280413]), array([-0.33783442]), array([-0.40956792]), array([-0.08019755]), array([-0.30659068]), array([0.12954913])]
# Params passed to generate_synthetic_data: [array([-1.39503015]), array([-0.86806963]), array([-0.6936365]), array([-1.10637413]), array([-0.32834432]), array([-0.38927684]), array([-0.0648041]), array([-0.34764988]), array([0.18549315])]
# Current params: [array([-1.10729454]), array([-0.79741429]), array([-1.03573647]), array([-1.08271846]), array([-1.05514026]), array([-0.6419704]), array([-0.45379012]), array([0.3306534]), array([-0.10989084])]
# Proposed params: [array([-1.13318258]), array([-0.7825413]), array([-1.01288126]), array([-1.10277353]), array([-0.95772021]), array([-0.80353809]), array([-0.51609666]), array([0.56923003]), array([-0.04645596])]
# Params passed to generate_synthetic_data: [array([-1.10729454]), array([-0.79741429]), array([-1.03573647]), array([-1.08271846]), array([-1.05514026]), array([-0.6419704]), array([-0.45379012]), array([0.3306534]), array([-0.10989084])]
# Params passed to generate_synthetic_data: [array([-1.13318258]), array([-0.7825413]), array([-1.01288126]), array([-1.10277353]), array([-0.95772021]), array([-0.80353809]), array([-0.51609666]), array([0.56923003]), array([-0.04645596])]
# Current params: [array([-1.39503015]), array([-0.86806963]), array([-0.6936365]), array([-1.10637413]), array([-0.32834432]), array([-0.38927684]), array([-0.0648041]), array([-0.34764988]), array([0.18549315])]
# Proposed params: [array([-1.44821819]), array([-0.98079335]), array([-0.66445418]), array([-1.09505539]), array([-0.29680988]), array([-0.4443453]), array([-0.20448042]), array([-0.40323438]), array([0.30383718])]
# Params passed to generate_synthetic_data: [array([-1.39503015]), array([-0.86806963]), array([-0.6936365]), array([-1.10637413]), array([-0.32834432]), array([-0.38927684]), array([-0.0648041]), array([-0.34764988]), array([0.18549315])]
# Params passed to generate_synthetic_data: [array([-1.44821819]), array([-0.98079335]), array([-0.66445418]), array([-1.09505539]), array([-0.29680988]), array([-0.4443453]), array([-0.20448042]), array([-0.40323438]), array([0.30383718])]
# Current params: [array([-1.13318258]), array([-0.7825413]), array([-1.01288126]), array([-1.10277353]), array([-0.95772021]), array([-0.80353809]), array([-0.51609666]), array([0.56923003]), array([-0.04645596])]
# Proposed params: [array([-1.29838088]), array([-0.82073014]), array([-0.95478038]), array([-0.93959482]), array([-0.92559987]), array([-0.88570032]), array([-0.45461186]), array([0.53282024]), array([-0.09004198])]
# Params passed to generate_synthetic_data: [array([-1.13318258]), array([-0.7825413]), array([-1.01288126]), array([-1.10277353]), array([-0.95772021]), array([-0.80353809]), array([-0.51609666]), array([0.56923003]), array([-0.04645596])]
# Params passed to generate_synthetic_data: [array([-1.29838088]), array([-0.82073014]), array([-0.95478038]), array([-0.93959482]), array([-0.92559987]), array([-0.88570032]), array([-0.45461186]), array([0.53282024]), array([-0.09004198])]
# Current params: [array([-1.44821819]), array([-0.98079335]), array([-0.66445418]), array([-1.09505539]), array([-0.29680988]), array([-0.4443453]), array([-0.20448042]), array([-0.40323438]), array([0.30383718])]
# Proposed params: [array([-1.62211367]), array([-1.03206569]), array([-0.76189589]), array([-1.10841082]), array([-0.23281152]), array([-0.48376786]), array([-0.20315972]), array([-0.4674675]), array([0.26316378])]
# Params passed to generate_synthetic_data: [array([-1.44821819]), array([-0.98079335]), array([-0.66445418]), array([-1.09505539]), array([-0.29680988]), array([-0.4443453]), array([-0.20448042]), array([-0.40323438]), array([0.30383718])]
# Params passed to generate_synthetic_data: [array([-1.62211367]), array([-1.03206569]), array([-0.76189589]), array([-1.10841082]), array([-0.23281152]), array([-0.48376786]), array([-0.20315972]), array([-0.4674675]), array([0.26316378])]
# Current params: [array([-1.29838088]), array([-0.82073014]), array([-0.95478038]), array([-0.93959482]), array([-0.92559987]), array([-0.88570032]), array([-0.45461186]), array([0.53282024]), array([-0.09004198])]
# Proposed params: [array([-1.30742958]), array([-0.79749029]), array([-0.80205528]), array([-1.00456443]), array([-0.8854584]), array([-0.92838995]), array([-0.55449477]), array([0.49414211]), array([-0.02419067])]
# Params passed to generate_synthetic_data: [array([-1.29838088]), array([-0.82073014]), array([-0.95478038]), array([-0.93959482]), array([-0.92559987]), array([-0.88570032]), array([-0.45461186]), array([0.53282024]), array([-0.09004198])]
# Params passed to generate_synthetic_data: [array([-1.30742958]), array([-0.79749029]), array([-0.80205528]), array([-1.00456443]), array([-0.8854584]), array([-0.92838995]), array([-0.55449477]), array([0.49414211]), array([-0.02419067])]
# Current params: [array([-1.30742958]), array([-0.79749029]), array([-0.80205528]), array([-1.00456443]), array([-0.8854584]), array([-0.92838995]), array([-0.55449477]), array([0.49414211]), array([-0.02419067])]
# Proposed params: [array([-1.39501349]), array([-0.75266682]), array([-0.72930886]), array([-0.97482351]), array([-0.76215839]), array([-1.08295302]), array([-0.67078254]), array([0.5812739]), array([0.06401408])]
# Params passed to generate_synthetic_data: [array([-1.30742958]), array([-0.79749029]), array([-0.80205528]), array([-1.00456443]), array([-0.8854584]), array([-0.92838995]), array([-0.55449477]), array([0.49414211]), array([-0.02419067])]
# Params passed to generate_synthetic_data: [array([-1.39501349]), array([-0.75266682]), array([-0.72930886]), array([-0.97482351]), array([-0.76215839]), array([-1.08295302]), array([-0.67078254]), array([0.5812739]), array([0.06401408])]
# Current params: [array([-1.62211367]), array([-1.03206569]), array([-0.76189589]), array([-1.10841082]), array([-0.23281152]), array([-0.48376786]), array([-0.20315972]), array([-0.4674675]), array([0.26316378])]
# Proposed params: [array([-1.64945079]), array([-1.09798057]), array([-0.66918424]), array([-1.16020152]), array([-0.47848466]), array([-0.74648916]), array([-0.17693554]), array([-0.25010445]), array([0.45343549])]
# Params passed to generate_synthetic_data: [array([-1.62211367]), array([-1.03206569]), array([-0.76189589]), array([-1.10841082]), array([-0.23281152]), array([-0.48376786]), array([-0.20315972]), array([-0.4674675]), array([0.26316378])]
# Params passed to generate_synthetic_data: [array([-1.64945079]), array([-1.09798057]), array([-0.66918424]), array([-1.16020152]), array([-0.47848466]), array([-0.74648916]), array([-0.17693554]), array([-0.25010445]), array([0.45343549])]
# Current params: [array([-1.64945079]), array([-1.09798057]), array([-0.66918424]), array([-1.16020152]), array([-0.47848466]), array([-0.74648916]), array([-0.17693554]), array([-0.25010445]), array([0.45343549])]
# Proposed params: [array([-1.6514134]), array([-1.17411666]), array([-0.97783982]), array([-1.07031166]), array([-0.53778148]), array([-0.77263937]), array([-0.18242014]), array([-0.28205918]), array([0.42586814])]
# Params passed to generate_synthetic_data: [array([-1.64945079]), array([-1.09798057]), array([-0.66918424]), array([-1.16020152]), array([-0.47848466]), array([-0.74648916]), array([-0.17693554]), array([-0.25010445]), array([0.45343549])]
# Params passed to generate_synthetic_data: [array([-1.6514134]), array([-1.17411666]), array([-0.97783982]), array([-1.07031166]), array([-0.53778148]), array([-0.77263937]), array([-0.18242014]), array([-0.28205918]), array([0.42586814])]
# Current params: [array([-1.39501349]), array([-0.75266682]), array([-0.72930886]), array([-0.97482351]), array([-0.76215839]), array([-1.08295302]), array([-0.67078254]), array([0.5812739]), array([0.06401408])]
# Proposed params: [array([-1.34804408]), array([-0.82866906]), array([-0.65123595]), array([-0.87103259]), array([-0.72011169]), array([-0.89580052]), array([-0.70003404]), array([0.54519277]), array([0.15694045])]
# Params passed to generate_synthetic_data: [array([-1.39501349]), array([-0.75266682]), array([-0.72930886]), array([-0.97482351]), array([-0.76215839]), array([-1.08295302]), array([-0.67078254]), array([0.5812739]), array([0.06401408])]
# Params passed to generate_synthetic_data: [array([-1.34804408]), array([-0.82866906]), array([-0.65123595]), array([-0.87103259]), array([-0.72011169]), array([-0.89580052]), array([-0.70003404]), array([0.54519277]), array([0.15694045])]
# Current params: [array([-1.34804408]), array([-0.82866906]), array([-0.65123595]), array([-0.87103259]), array([-0.72011169]), array([-0.89580052]), array([-0.70003404]), array([0.54519277]), array([0.15694045])]
# Proposed params: [array([-1.42037904]), array([-0.7379287]), array([-0.63165829]), array([-0.80205938]), array([-0.63795847]), array([-1.03350922]), array([-0.71993958]), array([0.49157615]), array([0.13239608])]
# Params passed to generate_synthetic_data: [array([-1.34804408]), array([-0.82866906]), array([-0.65123595]), array([-0.87103259]), array([-0.72011169]), array([-0.89580052]), array([-0.70003404]), array([0.54519277]), array([0.15694045])]
# Params passed to generate_synthetic_data: [array([-1.42037904]), array([-0.7379287]), array([-0.63165829]), array([-0.80205938]), array([-0.63795847]), array([-1.03350922]), array([-0.71993958]), array([0.49157615]), array([0.13239608])]
# Current params: [array([-1.6514134]), array([-1.17411666]), array([-0.97783982]), array([-1.07031166]), array([-0.53778148]), array([-0.77263937]), array([-0.18242014]), array([-0.28205918]), array([0.42586814])]
# Proposed params: [array([-1.73332876]), array([-1.27558461]), array([-0.89316709]), array([-1.1964729]), array([-0.74646707]), array([-0.71577263]), array([-0.25921057]), array([-0.18677168]), array([0.48577837])]
# Params passed to generate_synthetic_data: [array([-1.6514134]), array([-1.17411666]), array([-0.97783982]), array([-1.07031166]), array([-0.53778148]), array([-0.77263937]), array([-0.18242014]), array([-0.28205918]), array([0.42586814])]
# Params passed to generate_synthetic_data: [array([-1.73332876]), array([-1.27558461]), array([-0.89316709]), array([-1.1964729]), array([-0.74646707]), array([-0.71577263]), array([-0.25921057]), array([-0.18677168]), array([0.48577837])]
# Current params: [array([-1.42037904]), array([-0.7379287]), array([-0.63165829]), array([-0.80205938]), array([-0.63795847]), array([-1.03350922]), array([-0.71993958]), array([0.49157615]), array([0.13239608])]
# Proposed params: [array([-1.30809944]), array([-0.60185544]), array([-0.74123555]), array([-0.83067202]), array([-0.77997606]), array([-0.94891066]), array([-0.67446096]), array([0.64170307]), array([0.04901829])]
# Params passed to generate_synthetic_data: [array([-1.42037904]), array([-0.7379287]), array([-0.63165829]), array([-0.80205938]), array([-0.63795847]), array([-1.03350922]), array([-0.71993958]), array([0.49157615]), array([0.13239608])]
# Params passed to generate_synthetic_data: [array([-1.30809944]), array([-0.60185544]), array([-0.74123555]), array([-0.83067202]), array([-0.77997606]), array([-0.94891066]), array([-0.67446096]), array([0.64170307]), array([0.04901829])]
# Current params: [array([-1.73332876]), array([-1.27558461]), array([-0.89316709]), array([-1.1964729]), array([-0.74646707]), array([-0.71577263]), array([-0.25921057]), array([-0.18677168]), array([0.48577837])]
# Proposed params: [array([-1.78775071]), array([-1.14778345]), array([-0.87448682]), array([-1.14588248]), array([-0.75957075]), array([-0.50842881]), array([-0.25918599]), array([-0.2366162]), array([0.53419059])]
# Params passed to generate_synthetic_data: [array([-1.73332876]), array([-1.27558461]), array([-0.89316709]), array([-1.1964729]), array([-0.74646707]), array([-0.71577263]), array([-0.25921057]), array([-0.18677168]), array([0.48577837])]
# Params passed to generate_synthetic_data: [array([-1.78775071]), array([-1.14778345]), array([-0.87448682]), array([-1.14588248]), array([-0.75957075]), array([-0.50842881]), array([-0.25918599]), array([-0.2366162]), array([0.53419059])]
# Current params: [array([-1.78775071]), array([-1.14778345]), array([-0.87448682]), array([-1.14588248]), array([-0.75957075]), array([-0.50842881]), array([-0.25918599]), array([-0.2366162]), array([0.53419059])]
# Proposed params: [array([-1.76296592]), array([-1.18602561]), array([-0.80779502]), array([-1.0882348]), array([-0.72078606]), array([-0.34960766]), array([-0.19739633]), array([-0.2696394]), array([0.39157814])]
# Params passed to generate_synthetic_data: [array([-1.78775071]), array([-1.14778345]), array([-0.87448682]), array([-1.14588248]), array([-0.75957075]), array([-0.50842881]), array([-0.25918599]), array([-0.2366162]), array([0.53419059])]
# Params passed to generate_synthetic_data: [array([-1.76296592]), array([-1.18602561]), array([-0.80779502]), array([-1.0882348]), array([-0.72078606]), array([-0.34960766]), array([-0.19739633]), array([-0.2696394]), array([0.39157814])]
# Current params: [array([-1.30809944]), array([-0.60185544]), array([-0.74123555]), array([-0.83067202]), array([-0.77997606]), array([-0.94891066]), array([-0.67446096]), array([0.64170307]), array([0.04901829])]
# Proposed params: [array([-1.23165037]), array([-0.80588022]), array([-0.82999292]), array([-0.89962858]), array([-1.01019421]), array([-0.81816449]), array([-0.76152955]), array([0.58080405]), array([0.11471164])]
# Params passed to generate_synthetic_data: [array([-1.30809944]), array([-0.60185544]), array([-0.74123555]), array([-0.83067202]), array([-0.77997606]), array([-0.94891066]), array([-0.67446096]), array([0.64170307]), array([0.04901829])]
# Params passed to generate_synthetic_data: [array([-1.23165037]), array([-0.80588022]), array([-0.82999292]), array([-0.89962858]), array([-1.01019421]), array([-0.81816449]), array([-0.76152955]), array([0.58080405]), array([0.11471164])]
# Current params: [array([-1.76296592]), array([-1.18602561]), array([-0.80779502]), array([-1.0882348]), array([-0.72078606]), array([-0.34960766]), array([-0.19739633]), array([-0.2696394]), array([0.39157814])]
# Proposed params: [array([-1.79811717]), array([-1.17212632]), array([-0.69790955]), array([-0.96018973]), array([-0.71282283]), array([-0.49256187]), array([-0.27395298]), array([-0.47081389]), array([0.38433503])]
# Params passed to generate_synthetic_data: [array([-1.76296592]), array([-1.18602561]), array([-0.80779502]), array([-1.0882348]), array([-0.72078606]), array([-0.34960766]), array([-0.19739633]), array([-0.2696394]), array([0.39157814])]
# Params passed to generate_synthetic_data: [array([-1.79811717]), array([-1.17212632]), array([-0.69790955]), array([-0.96018973]), array([-0.71282283]), array([-0.49256187]), array([-0.27395298]), array([-0.47081389]), array([0.38433503])]
# Current params: [array([-1.23165037]), array([-0.80588022]), array([-0.82999292]), array([-0.89962858]), array([-1.01019421]), array([-0.81816449]), array([-0.76152955]), array([0.58080405]), array([0.11471164])]
# Proposed params: [array([-1.25428323]), array([-0.92702056]), array([-0.67034943]), array([-0.81605999]), array([-0.95721695]), array([-0.8859368]), array([-0.71421225]), array([0.35294884]), array([0.14053921])]
# Params passed to generate_synthetic_data: [array([-1.23165037]), array([-0.80588022]), array([-0.82999292]), array([-0.89962858]), array([-1.01019421]), array([-0.81816449]), array([-0.76152955]), array([0.58080405]), array([0.11471164])]
# Params passed to generate_synthetic_data: [array([-1.25428323]), array([-0.92702056]), array([-0.67034943]), array([-0.81605999]), array([-0.95721695]), array([-0.8859368]), array([-0.71421225]), array([0.35294884]), array([0.14053921])]
# Current params: [array([-1.79811717]), array([-1.17212632]), array([-0.69790955]), array([-0.96018973]), array([-0.71282283]), array([-0.49256187]), array([-0.27395298]), array([-0.47081389]), array([0.38433503])]
# Proposed params: [array([-1.87140235]), array([-1.21060943]), array([-0.68225863]), array([-0.93185997]), array([-0.67047374]), array([-0.43089429]), array([-0.35048128]), array([-0.56103439]), array([0.36888294])]
# Params passed to generate_synthetic_data: [array([-1.79811717]), array([-1.17212632]), array([-0.69790955]), array([-0.96018973]), array([-0.71282283]), array([-0.49256187]), array([-0.27395298]), array([-0.47081389]), array([0.38433503])]
# Params passed to generate_synthetic_data: [array([-1.87140235]), array([-1.21060943]), array([-0.68225863]), array([-0.93185997]), array([-0.67047374]), array([-0.43089429]), array([-0.35048128]), array([-0.56103439]), array([0.36888294])]
# Current params: [array([-1.25428323]), array([-0.92702056]), array([-0.67034943]), array([-0.81605999]), array([-0.95721695]), array([-0.8859368]), array([-0.71421225]), array([0.35294884]), array([0.14053921])]
# Proposed params: [array([-1.15300685]), array([-0.8001562]), array([-0.65661723]), array([-0.72556393]), array([-1.00295496]), array([-0.91769839]), array([-0.77947212]), array([0.28913066]), array([0.13579892])]
# Params passed to generate_synthetic_data: [array([-1.25428323]), array([-0.92702056]), array([-0.67034943]), array([-0.81605999]), array([-0.95721695]), array([-0.8859368]), array([-0.71421225]), array([0.35294884]), array([0.14053921])]
# Params passed to generate_synthetic_data: [array([-1.15300685]), array([-0.8001562]), array([-0.65661723]), array([-0.72556393]), array([-1.00295496]), array([-0.91769839]), array([-0.77947212]), array([0.28913066]), array([0.13579892])]
# Current params: [array([-1.15300685]), array([-0.8001562]), array([-0.65661723]), array([-0.72556393]), array([-1.00295496]), array([-0.91769839]), array([-0.77947212]), array([0.28913066]), array([0.13579892])]
# Proposed params: [array([-1.06054724]), array([-0.85565378]), array([-0.7053824]), array([-0.7427206]), array([-0.9375509]), array([-0.89114586]), array([-0.87936231]), array([0.29541541]), array([0.01894653])]
# Params passed to generate_synthetic_data: [array([-1.15300685]), array([-0.8001562]), array([-0.65661723]), array([-0.72556393]), array([-1.00295496]), array([-0.91769839]), array([-0.77947212]), array([0.28913066]), array([0.13579892])]
# Params passed to generate_synthetic_data: [array([-1.06054724]), array([-0.85565378]), array([-0.7053824]), array([-0.7427206]), array([-0.9375509]), array([-0.89114586]), array([-0.87936231]), array([0.29541541]), array([0.01894653])]
# Current params: [array([-1.87140235]), array([-1.21060943]), array([-0.68225863]), array([-0.93185997]), array([-0.67047374]), array([-0.43089429]), array([-0.35048128]), array([-0.56103439]), array([0.36888294])]
# Proposed params: [array([-2.02063615]), array([-1.09408081]), array([-0.70125543]), array([-0.90524879]), array([-0.75255282]), array([-0.52020137]), array([-0.37584585]), array([-0.66677183]), array([0.34876944])]
# Params passed to generate_synthetic_data: [array([-1.87140235]), array([-1.21060943]), array([-0.68225863]), array([-0.93185997]), array([-0.67047374]), array([-0.43089429]), array([-0.35048128]), array([-0.56103439]), array([0.36888294])]
# Params passed to generate_synthetic_data: [array([-2.02063615]), array([-1.09408081]), array([-0.70125543]), array([-0.90524879]), array([-0.75255282]), array([-0.52020137]), array([-0.37584585]), array([-0.66677183]), array([0.34876944])]
# Current params: [array([-2.02063615]), array([-1.09408081]), array([-0.70125543]), array([-0.90524879]), array([-0.75255282]), array([-0.52020137]), array([-0.37584585]), array([-0.66677183]), array([0.34876944])]
# Proposed params: [array([-1.99811603]), array([-1.16660618]), array([-0.60704669]), array([-0.97353648]), array([-0.84717164]), array([-0.48815391]), array([-0.38373023]), array([-0.61103622]), array([0.35002301])]
# Params passed to generate_synthetic_data: [array([-2.02063615]), array([-1.09408081]), array([-0.70125543]), array([-0.90524879]), array([-0.75255282]), array([-0.52020137]), array([-0.37584585]), array([-0.66677183]), array([0.34876944])]
# Params passed to generate_synthetic_data: [array([-1.99811603]), array([-1.16660618]), array([-0.60704669]), array([-0.97353648]), array([-0.84717164]), array([-0.48815391]), array([-0.38373023]), array([-0.61103622]), array([0.35002301])]
# Current params: [array([-1.06054724]), array([-0.85565378]), array([-0.7053824]), array([-0.7427206]), array([-0.9375509]), array([-0.89114586]), array([-0.87936231]), array([0.29541541]), array([0.01894653])]
# Proposed params: [array([-0.97772484]), array([-0.77618578]), array([-0.63869335]), array([-0.91548151]), array([-0.90496939]), array([-0.89030343]), array([-0.83721014]), array([0.14223621]), array([0.04989419])]
# Params passed to generate_synthetic_data: [array([-1.06054724]), array([-0.85565378]), array([-0.7053824]), array([-0.7427206]), array([-0.9375509]), array([-0.89114586]), array([-0.87936231]), array([0.29541541]), array([0.01894653])]
# Params passed to generate_synthetic_data: [array([-0.97772484]), array([-0.77618578]), array([-0.63869335]), array([-0.91548151]), array([-0.90496939]), array([-0.89030343]), array([-0.83721014]), array([0.14223621]), array([0.04989419])]
# Current params: [array([-0.97772484]), array([-0.77618578]), array([-0.63869335]), array([-0.91548151]), array([-0.90496939]), array([-0.89030343]), array([-0.83721014]), array([0.14223621]), array([0.04989419])]
# Proposed params: [array([-0.98315793]), array([-0.72790974]), array([-0.80705231]), array([-0.9640719]), array([-1.02230532]), array([-0.86887829]), array([-0.92867934]), array([0.16931407]), array([0.00677985])]
# Params passed to generate_synthetic_data: [array([-0.97772484]), array([-0.77618578]), array([-0.63869335]), array([-0.91548151]), array([-0.90496939]), array([-0.89030343]), array([-0.83721014]), array([0.14223621]), array([0.04989419])]
# Params passed to generate_synthetic_data: [array([-0.98315793]), array([-0.72790974]), array([-0.80705231]), array([-0.9640719]), array([-1.02230532]), array([-0.86887829]), array([-0.92867934]), array([0.16931407]), array([0.00677985])]
# Current params: [array([-1.99811603]), array([-1.16660618]), array([-0.60704669]), array([-0.97353648]), array([-0.84717164]), array([-0.48815391]), array([-0.38373023]), array([-0.61103622]), array([0.35002301])]
# Proposed params: [array([-2.08731074]), array([-1.09824823]), array([-0.74339761]), array([-1.01759335]), array([-0.94971736]), array([-0.58466341]), array([-0.43172717]), array([-0.81723476]), array([0.29044891])]
# Params passed to generate_synthetic_data: [array([-1.99811603]), array([-1.16660618]), array([-0.60704669]), array([-0.97353648]), array([-0.84717164]), array([-0.48815391]), array([-0.38373023]), array([-0.61103622]), array([0.35002301])]
# Params passed to generate_synthetic_data: [array([-2.08731074]), array([-1.09824823]), array([-0.74339761]), array([-1.01759335]), array([-0.94971736]), array([-0.58466341]), array([-0.43172717]), array([-0.81723476]), array([0.29044891])]
# Current params: [array([-0.98315793]), array([-0.72790974]), array([-0.80705231]), array([-0.9640719]), array([-1.02230532]), array([-0.86887829]), array([-0.92867934]), array([0.16931407]), array([0.00677985])]
# Proposed params: [array([-0.78243]), array([-0.99946409]), array([-0.97932532]), array([-0.80890208]), array([-1.09924143]), array([-0.95741949]), array([-0.93812496]), array([0.36825931]), array([-0.01178333])]
# Params passed to generate_synthetic_data: [array([-0.98315793]), array([-0.72790974]), array([-0.80705231]), array([-0.9640719]), array([-1.02230532]), array([-0.86887829]), array([-0.92867934]), array([0.16931407]), array([0.00677985])]
# Params passed to generate_synthetic_data: [array([-0.78243]), array([-0.99946409]), array([-0.97932532]), array([-0.80890208]), array([-1.09924143]), array([-0.95741949]), array([-0.93812496]), array([0.36825931]), array([-0.01178333])]
# Current params: [array([-2.08731074]), array([-1.09824823]), array([-0.74339761]), array([-1.01759335]), array([-0.94971736]), array([-0.58466341]), array([-0.43172717]), array([-0.81723476]), array([0.29044891])]
# Proposed params: [array([-2.17373354]), array([-1.16774842]), array([-0.74001017]), array([-0.8926086]), array([-1.03135878]), array([-0.56132358]), array([-0.45432954]), array([-0.87813972]), array([0.29333962])]
# Params passed to generate_synthetic_data: [array([-2.08731074]), array([-1.09824823]), array([-0.74339761]), array([-1.01759335]), array([-0.94971736]), array([-0.58466341]), array([-0.43172717]), array([-0.81723476]), array([0.29044891])]
# Params passed to generate_synthetic_data: [array([-2.17373354]), array([-1.16774842]), array([-0.74001017]), array([-0.8926086]), array([-1.03135878]), array([-0.56132358]), array([-0.45432954]), array([-0.87813972]), array([0.29333962])]
# Current params: [array([-0.78243]), array([-0.99946409]), array([-0.97932532]), array([-0.80890208]), array([-1.09924143]), array([-0.95741949]), array([-0.93812496]), array([0.36825931]), array([-0.01178333])]
# Proposed params: [array([-0.64291588]), array([-1.0360334]), array([-0.93993827]), array([-0.70144118]), array([-1.00413663]), array([-0.98208039]), array([-1.00158346]), array([0.44124468]), array([-0.02073069])]
# Params passed to generate_synthetic_data: [array([-0.78243]), array([-0.99946409]), array([-0.97932532]), array([-0.80890208]), array([-1.09924143]), array([-0.95741949]), array([-0.93812496]), array([0.36825931]), array([-0.01178333])]
# Params passed to generate_synthetic_data: [array([-0.64291588]), array([-1.0360334]), array([-0.93993827]), array([-0.70144118]), array([-1.00413663]), array([-0.98208039]), array([-1.00158346]), array([0.44124468]), array([-0.02073069])]
# Current params: [array([-2.17373354]), array([-1.16774842]), array([-0.74001017]), array([-0.8926086]), array([-1.03135878]), array([-0.56132358]), array([-0.45432954]), array([-0.87813972]), array([0.29333962])]
# Proposed params: [array([-2.23402021]), array([-1.23669753]), array([-0.9766532]), array([-0.84200695]), array([-0.9092946]), array([-0.56927693]), array([-0.23346055]), array([-0.99612407]), array([0.37849058])]
# Params passed to generate_synthetic_data: [array([-2.17373354]), array([-1.16774842]), array([-0.74001017]), array([-0.8926086]), array([-1.03135878]), array([-0.56132358]), array([-0.45432954]), array([-0.87813972]), array([0.29333962])]
# Params passed to generate_synthetic_data: [array([-2.23402021]), array([-1.23669753]), array([-0.9766532]), array([-0.84200695]), array([-0.9092946]), array([-0.56927693]), array([-0.23346055]), array([-0.99612407]), array([0.37849058])]
# Current params: [array([-0.64291588]), array([-1.0360334]), array([-0.93993827]), array([-0.70144118]), array([-1.00413663]), array([-0.98208039]), array([-1.00158346]), array([0.44124468]), array([-0.02073069])]
# Proposed params: [array([-0.53657947]), array([-1.19494712]), array([-0.9422205]), array([-0.50657562]), array([-1.16479167]), array([-0.92055472]), array([-1.17618942]), array([0.50057277]), array([-0.15961707])]
# Params passed to generate_synthetic_data: [array([-0.64291588]), array([-1.0360334]), array([-0.93993827]), array([-0.70144118]), array([-1.00413663]), array([-0.98208039]), array([-1.00158346]), array([0.44124468]), array([-0.02073069])]
# Params passed to generate_synthetic_data: [array([-0.53657947]), array([-1.19494712]), array([-0.9422205]), array([-0.50657562]), array([-1.16479167]), array([-0.92055472]), array([-1.17618942]), array([0.50057277]), array([-0.15961707])]
# Current params: [array([-2.23402021]), array([-1.23669753]), array([-0.9766532]), array([-0.84200695]), array([-0.9092946]), array([-0.56927693]), array([-0.23346055]), array([-0.99612407]), array([0.37849058])]
# Proposed params: [array([-2.06333604]), array([-1.27013935]), array([-0.8344599]), array([-0.9352793]), array([-0.78864895]), array([-0.63522664]), array([-0.20119737]), array([-1.01020493]), array([0.22265241])]
# Params passed to generate_synthetic_data: [array([-2.23402021]), array([-1.23669753]), array([-0.9766532]), array([-0.84200695]), array([-0.9092946]), array([-0.56927693]), array([-0.23346055]), array([-0.99612407]), array([0.37849058])]
# Params passed to generate_synthetic_data: [array([-2.06333604]), array([-1.27013935]), array([-0.8344599]), array([-0.9352793]), array([-0.78864895]), array([-0.63522664]), array([-0.20119737]), array([-1.01020493]), array([0.22265241])]
# Current params: [array([-0.53657947]), array([-1.19494712]), array([-0.9422205]), array([-0.50657562]), array([-1.16479167]), array([-0.92055472]), array([-1.17618942]), array([0.50057277]), array([-0.15961707])]
# Proposed params: [array([-0.44734139]), array([-1.22878965]), array([-0.92078587]), array([-0.36784504]), array([-1.01211523]), array([-0.92056332]), array([-1.1940584]), array([0.42892472]), array([-0.05163344])]
# Params passed to generate_synthetic_data: [array([-0.53657947]), array([-1.19494712]), array([-0.9422205]), array([-0.50657562]), array([-1.16479167]), array([-0.92055472]), array([-1.17618942]), array([0.50057277]), array([-0.15961707])]
# Params passed to generate_synthetic_data: [array([-0.44734139]), array([-1.22878965]), array([-0.92078587]), array([-0.36784504]), array([-1.01211523]), array([-0.92056332]), array([-1.1940584]), array([0.42892472]), array([-0.05163344])]
# Current params: [array([-2.06333604]), array([-1.27013935]), array([-0.8344599]), array([-0.9352793]), array([-0.78864895]), array([-0.63522664]), array([-0.20119737]), array([-1.01020493]), array([0.22265241])]
# Proposed params: [array([-1.92481691]), array([-1.32658614]), array([-0.90575612]), array([-0.90655485]), array([-0.72320936]), array([-0.56023222]), array([-0.10806895]), array([-1.11250934]), array([0.2282677])]
# Params passed to generate_synthetic_data: [array([-2.06333604]), array([-1.27013935]), array([-0.8344599]), array([-0.9352793]), array([-0.78864895]), array([-0.63522664]), array([-0.20119737]), array([-1.01020493]), array([0.22265241])]
# Params passed to generate_synthetic_data: [array([-1.92481691]), array([-1.32658614]), array([-0.90575612]), array([-0.90655485]), array([-0.72320936]), array([-0.56023222]), array([-0.10806895]), array([-1.11250934]), array([0.2282677])]
# Current params: [array([-0.44734139]), array([-1.22878965]), array([-0.92078587]), array([-0.36784504]), array([-1.01211523]), array([-0.92056332]), array([-1.1940584]), array([0.42892472]), array([-0.05163344])]
# Proposed params: [array([-0.5184681]), array([-1.20824366]), array([-1.02474508]), array([-0.28301058]), array([-0.82107429]), array([-1.02237941]), array([-1.24782714]), array([0.37953338]), array([0.08771999])]
# Params passed to generate_synthetic_data: [array([-0.44734139]), array([-1.22878965]), array([-0.92078587]), array([-0.36784504]), array([-1.01211523]), array([-0.92056332]), array([-1.1940584]), array([0.42892472]), array([-0.05163344])]
# Params passed to generate_synthetic_data: [array([-0.5184681]), array([-1.20824366]), array([-1.02474508]), array([-0.28301058]), array([-0.82107429]), array([-1.02237941]), array([-1.24782714]), array([0.37953338]), array([0.08771999])]
# Current params: [array([-1.92481691]), array([-1.32658614]), array([-0.90575612]), array([-0.90655485]), array([-0.72320936]), array([-0.56023222]), array([-0.10806895]), array([-1.11250934]), array([0.2282677])]
# Proposed params: [array([-2.00233416]), array([-1.1988154]), array([-0.69425414]), array([-0.79693969]), array([-0.59849628]), array([-0.61039082]), array([-0.28424172]), array([-0.96732346]), array([0.09632202])]
# Params passed to generate_synthetic_data: [array([-1.92481691]), array([-1.32658614]), array([-0.90575612]), array([-0.90655485]), array([-0.72320936]), array([-0.56023222]), array([-0.10806895]), array([-1.11250934]), array([0.2282677])]
# Params passed to generate_synthetic_data: [array([-2.00233416]), array([-1.1988154]), array([-0.69425414]), array([-0.79693969]), array([-0.59849628]), array([-0.61039082]), array([-0.28424172]), array([-0.96732346]), array([0.09632202])]
# Current params: [array([-0.5184681]), array([-1.20824366]), array([-1.02474508]), array([-0.28301058]), array([-0.82107429]), array([-1.02237941]), array([-1.24782714]), array([0.37953338]), array([0.08771999])]
# Proposed params: [array([-0.59540903]), array([-1.19819417]), array([-1.15137167]), array([-0.19986258]), array([-0.97777066]), array([-0.98570939]), array([-1.28007361]), array([0.19119901]), array([0.23889681])]
# Params passed to generate_synthetic_data: [array([-0.5184681]), array([-1.20824366]), array([-1.02474508]), array([-0.28301058]), array([-0.82107429]), array([-1.02237941]), array([-1.24782714]), array([0.37953338]), array([0.08771999])]
# Params passed to generate_synthetic_data: [array([-0.59540903]), array([-1.19819417]), array([-1.15137167]), array([-0.19986258]), array([-0.97777066]), array([-0.98570939]), array([-1.28007361]), array([0.19119901]), array([0.23889681])]
# ...
# Params passed to generate_synthetic_data: [array([-2.00407905]), array([-1.04853459]), array([-0.67583309]), array([-0.76987439]), array([-0.36988051]), array([-0.51137182]), array([-0.31371269]), array([-1.09898996]), array([-0.09508895])]
# Params passed to generate_synthetic_data: [array([-1.98586199]), array([-1.0755113]), array([-0.67020426]), array([-0.59790846]), array([-0.44519565]), array([-0.54367129]), array([-0.23375309]), array([-1.1489607]), array([0.03315143])]
# Current params: [array([-1.98586199]), array([-1.0755113]), array([-0.67020426]), array([-0.59790846]), array([-0.44519565]), array([-0.54367129]), array([-0.23375309]), array([-1.1489607]), array([0.03315143])]
# Proposed params: [array([-2.08445555]), array([-1.20996794]), array([-0.75053433]), array([-0.56475014]), array([-0.54785646]), array([-0.58510662]), array([-0.1948471]), array([-1.09278261]), array([0.01657576])]
# Params passed to generate_synthetic_data: [array([-1.98586199]), array([-1.0755113]), array([-0.67020426]), array([-0.59790846]), array([-0.44519565]), array([-0.54367129]), array([-0.23375309]), array([-1.1489607]), array([0.03315143])]
# Params passed to generate_synthetic_data: [array([-2.08445555]), array([-1.20996794]), array([-0.75053433]), array([-0.56475014]), array([-0.54785646]), array([-0.58510662]), array([-0.1948471]), array([-1.09278261]), array([0.01657576])]
# Current params: [array([-0.69689558]), array([-1.29689816]), array([-1.10493647]), array([-0.09632849]), array([-1.24772901]), array([-1.03401282]), array([-1.23173617]), array([0.25305046]), array([0.40061773])]
# Proposed params: [array([-0.73651283]), array([-1.31826359]), array([-1.11578345]), array([-0.04513173]), array([-1.36440893]), array([-1.06845409]), array([-1.08183694]), array([0.06090317]), array([0.41632818])]
# Params passed to generate_synthetic_data: [array([-0.69689558]), array([-1.29689816]), array([-1.10493647]), array([-0.09632849]), array([-1.24772901]), array([-1.03401282]), array([-1.23173617]), array([0.25305046]), array([0.40061773])]
# Params passed to generate_synthetic_data: [array([-0.73651283]), array([-1.31826359]), array([-1.11578345]), array([-0.04513173]), array([-1.36440893]), array([-1.06845409]), array([-1.08183694]), array([0.06090317]), array([0.41632818])]
# Current params: [array([-2.08445555]), array([-1.20996794]), array([-0.75053433]), array([-0.56475014]), array([-0.54785646]), array([-0.58510662]), array([-0.1948471]), array([-1.09278261]), array([0.01657576])]
# Proposed params: [array([-2.18073356]), array([-1.19490004]), array([-0.77054493]), array([-0.68038897]), array([-0.40279424]), array([-0.55583484]), array([-0.13961297]), array([-0.99331568]), array([0.07547135])]
# Params passed to generate_synthetic_data: [array([-2.08445555]), array([-1.20996794]), array([-0.75053433]), array([-0.56475014]), array([-0.54785646]), array([-0.58510662]), array([-0.1948471]), array([-1.09278261]), array([0.01657576])]
# Params passed to generate_synthetic_data: [array([-2.18073356]), array([-1.19490004]), array([-0.77054493]), array([-0.68038897]), array([-0.40279424]), array([-0.55583484]), array([-0.13961297]), array([-0.99331568]), array([0.07547135])]
# Current params: [array([-0.73651283]), array([-1.31826359]), array([-1.11578345]), array([-0.04513173]), array([-1.36440893]), array([-1.06845409]), array([-1.08183694]), array([0.06090317]), array([0.41632818])]
# Proposed params: [array([-0.81427314]), array([-1.39495368]), array([-0.91955035]), array([0.1011475]), array([-1.46446752]), array([-1.01301666]), array([-1.09285596]), array([0.1264057]), array([0.49403725])]
# Params passed to generate_synthetic_data: [array([-0.73651283]), array([-1.31826359]), array([-1.11578345]), array([-0.04513173]), array([-1.36440893]), array([-1.06845409]), array([-1.08183694]), array([0.06090317]), array([0.41632818])]
# Params passed to generate_synthetic_data: [array([-0.81427314]), array([-1.39495368]), array([-0.91955035]), array([0.1011475]), array([-1.46446752]), array([-1.01301666]), array([-1.09285596]), array([0.1264057]), array([0.49403725])]
# Current params: [array([-0.81427314]), array([-1.39495368]), array([-0.91955035]), array([0.1011475]), array([-1.46446752]), array([-1.01301666]), array([-1.09285596]), array([0.1264057]), array([0.49403725])]
# Proposed params: [array([-0.91935662]), array([-1.43475563]), array([-1.03282648]), array([0.06232495]), array([-1.50471018]), array([-0.94633513]), array([-1.16979335]), array([0.19217094]), array([0.46966868])]
# Params passed to generate_synthetic_data: [array([-0.81427314]), array([-1.39495368]), array([-0.91955035]), array([0.1011475]), array([-1.46446752]), array([-1.01301666]), array([-1.09285596]), array([0.1264057]), array([0.49403725])]
# Params passed to generate_synthetic_data: [array([-0.91935662]), array([-1.43475563]), array([-1.03282648]), array([0.06232495]), array([-1.50471018]), array([-0.94633513]), array([-1.16979335]), array([0.19217094]), array([0.46966868])]
# Current params: [array([-2.18073356]), array([-1.19490004]), array([-0.77054493]), array([-0.68038897]), array([-0.40279424]), array([-0.55583484]), array([-0.13961297]), array([-0.99331568]), array([0.07547135])]
# Proposed params: [array([-2.21444329]), array([-1.15100851]), array([-1.01947343]), array([-0.67692847]), array([-0.33222628]), array([-0.52499321]), array([-0.36632013]), array([-1.05156476]), array([0.16539969])]
# Params passed to generate_synthetic_data: [array([-2.18073356]), array([-1.19490004]), array([-0.77054493]), array([-0.68038897]), array([-0.40279424]), array([-0.55583484]), array([-0.13961297]), array([-0.99331568]), array([0.07547135])]
# Params passed to generate_synthetic_data: [array([-2.21444329]), array([-1.15100851]), array([-1.01947343]), array([-0.67692847]), array([-0.33222628]), array([-0.52499321]), array([-0.36632013]), array([-1.05156476]), array([0.16539969])]
# Current params: [array([-2.21444329]), array([-1.15100851]), array([-1.01947343]), array([-0.67692847]), array([-0.33222628]), array([-0.52499321]), array([-0.36632013]), array([-1.05156476]), array([0.16539969])]
# Proposed params: [array([-2.25780602]), array([-1.07878992]), array([-1.0361473]), array([-0.70010704]), array([-0.51517922]), array([-0.38834468]), array([-0.41272181]), array([-1.03591453]), array([0.27437361])]
# Params passed to generate_synthetic_data: [array([-2.21444329]), array([-1.15100851]), array([-1.01947343]), array([-0.67692847]), array([-0.33222628]), array([-0.52499321]), array([-0.36632013]), array([-1.05156476]), array([0.16539969])]
# Params passed to generate_synthetic_data: [array([-2.25780602]), array([-1.07878992]), array([-1.0361473]), array([-0.70010704]), array([-0.51517922]), array([-0.38834468]), array([-0.41272181]), array([-1.03591453]), array([0.27437361])]
# Current params: [array([-0.91935662]), array([-1.43475563]), array([-1.03282648]), array([0.06232495]), array([-1.50471018]), array([-0.94633513]), array([-1.16979335]), array([0.19217094]), array([0.46966868])]
# Proposed params: [array([-0.9252354]), array([-1.46714478]), array([-1.01154929]), array([0.04237641]), array([-1.50710576]), array([-1.02093561]), array([-1.17486428]), array([0.31013858]), array([0.45661432])]
# Params passed to generate_synthetic_data: [array([-0.91935662]), array([-1.43475563]), array([-1.03282648]), array([0.06232495]), array([-1.50471018]), array([-0.94633513]), array([-1.16979335]), array([0.19217094]), array([0.46966868])]
# Params passed to generate_synthetic_data: [array([-0.9252354]), array([-1.46714478]), array([-1.01154929]), array([0.04237641]), array([-1.50710576]), array([-1.02093561]), array([-1.17486428]), array([0.31013858]), array([0.45661432])]
# Current params: [array([-2.25780602]), array([-1.07878992]), array([-1.0361473]), array([-0.70010704]), array([-0.51517922]), array([-0.38834468]), array([-0.41272181]), array([-1.03591453]), array([0.27437361])]
# Proposed params: [array([-2.39488954]), array([-1.1086719]), array([-1.07008903]), array([-0.67596198]), array([-0.63124748]), array([-0.37818416]), array([-0.29699881]), array([-1.04414009]), array([0.2457933])]
# Params passed to generate_synthetic_data: [array([-2.25780602]), array([-1.07878992]), array([-1.0361473]), array([-0.70010704]), array([-0.51517922]), array([-0.38834468]), array([-0.41272181]), array([-1.03591453]), array([0.27437361])]
# Params passed to generate_synthetic_data: [array([-2.39488954]), array([-1.1086719]), array([-1.07008903]), array([-0.67596198]), array([-0.63124748]), array([-0.37818416]), array([-0.29699881]), array([-1.04414009]), array([0.2457933])]
# Current params: [array([-0.9252354]), array([-1.46714478]), array([-1.01154929]), array([0.04237641]), array([-1.50710576]), array([-1.02093561]), array([-1.17486428]), array([0.31013858]), array([0.45661432])]
# Proposed params: [array([-0.9427669]), array([-1.56841963]), array([-0.94612661]), array([-0.01070762]), array([-1.42309871]), array([-1.12841063]), array([-1.23942561]), array([0.14191393]), array([0.43272697])]
# Params passed to generate_synthetic_data: [array([-0.9252354]), array([-1.46714478]), array([-1.01154929]), array([0.04237641]), array([-1.50710576]), array([-1.02093561]), array([-1.17486428]), array([0.31013858]), array([0.45661432])]
# Params passed to generate_synthetic_data: [array([-0.9427669]), array([-1.56841963]), array([-0.94612661]), array([-0.01070762]), array([-1.42309871]), array([-1.12841063]), array([-1.23942561]), array([0.14191393]), array([0.43272697])]
# Current params: [array([-2.39488954]), array([-1.1086719]), array([-1.07008903]), array([-0.67596198]), array([-0.63124748]), array([-0.37818416]), array([-0.29699881]), array([-1.04414009]), array([0.2457933])]
# Proposed params: [array([-2.3482897]), array([-1.10464619]), array([-0.98905051]), array([-0.69277455]), array([-0.62820122]), array([-0.3803384]), array([-0.23476925]), array([-0.8671666]), array([0.31790666])]
# Params passed to generate_synthetic_data: [array([-2.39488954]), array([-1.1086719]), array([-1.07008903]), array([-0.67596198]), array([-0.63124748]), array([-0.37818416]), array([-0.29699881]), array([-1.04414009]), array([0.2457933])]
# Params passed to generate_synthetic_data: [array([-2.3482897]), array([-1.10464619]), array([-0.98905051]), array([-0.69277455]), array([-0.62820122]), array([-0.3803384]), array([-0.23476925]), array([-0.8671666]), array([0.31790666])]
# Current params: [array([-0.9427669]), array([-1.56841963]), array([-0.94612661]), array([-0.01070762]), array([-1.42309871]), array([-1.12841063]), array([-1.23942561]), array([0.14191393]), array([0.43272697])]
# Proposed params: [array([-0.84082145]), array([-1.46194366]), array([-0.86617731]), array([0.13280703]), array([-1.21192354]), array([-0.95372016]), array([-1.27235322]), array([0.06444161]), array([0.69893276])]
# Params passed to generate_synthetic_data: [array([-0.9427669]), array([-1.56841963]), array([-0.94612661]), array([-0.01070762]), array([-1.42309871]), array([-1.12841063]), array([-1.23942561]), array([0.14191393]), array([0.43272697])]
# Params passed to generate_synthetic_data: [array([-0.84082145]), array([-1.46194366]), array([-0.86617731]), array([0.13280703]), array([-1.21192354]), array([-0.95372016]), array([-1.27235322]), array([0.06444161]), array([0.69893276])]
# Current params: [array([-0.84082145]), array([-1.46194366]), array([-0.86617731]), array([0.13280703]), array([-1.21192354]), array([-0.95372016]), array([-1.27235322]), array([0.06444161]), array([0.69893276])]
# Proposed params: [array([-0.89381004]), array([-1.61357151]), array([-0.81244093]), array([0.04377554]), array([-1.14931687]), array([-0.84949757]), array([-1.19782144]), array([0.01305548]), array([0.77498601])]
# Params passed to generate_synthetic_data: [array([-0.84082145]), array([-1.46194366]), array([-0.86617731]), array([0.13280703]), array([-1.21192354]), array([-0.95372016]), array([-1.27235322]), array([0.06444161]), array([0.69893276])]
# Params passed to generate_synthetic_data: [array([-0.89381004]), array([-1.61357151]), array([-0.81244093]), array([0.04377554]), array([-1.14931687]), array([-0.84949757]), array([-1.19782144]), array([0.01305548]), array([0.77498601])]
# Current params: [array([-2.3482897]), array([-1.10464619]), array([-0.98905051]), array([-0.69277455]), array([-0.62820122]), array([-0.3803384]), array([-0.23476925]), array([-0.8671666]), array([0.31790666])]
# Proposed params: [array([-2.30194251]), array([-1.08160421]), array([-0.99178093]), array([-0.71707109]), array([-0.58839018]), array([-0.27868816]), array([-0.09809632]), array([-0.79430142]), array([0.46167848])]
# Params passed to generate_synthetic_data: [array([-2.3482897]), array([-1.10464619]), array([-0.98905051]), array([-0.69277455]), array([-0.62820122]), array([-0.3803384]), array([-0.23476925]), array([-0.8671666]), array([0.31790666])]
# Params passed to generate_synthetic_data: [array([-2.30194251]), array([-1.08160421]), array([-0.99178093]), array([-0.71707109]), array([-0.58839018]), array([-0.27868816]), array([-0.09809632]), array([-0.79430142]), array([0.46167848])]
# Current params: [array([-0.89381004]), array([-1.61357151]), array([-0.81244093]), array([0.04377554]), array([-1.14931687]), array([-0.84949757]), array([-1.19782144]), array([0.01305548]), array([0.77498601])]
# Proposed params: [array([-1.05040374]), array([-1.48818374]), array([-0.68391704]), array([-0.04419421]), array([-1.24364086]), array([-0.84883343]), array([-1.2662759]), array([0.06104454]), array([0.71195811])]
# Params passed to generate_synthetic_data: [array([-0.89381004]), array([-1.61357151]), array([-0.81244093]), array([0.04377554]), array([-1.14931687]), array([-0.84949757]), array([-1.19782144]), array([0.01305548]), array([0.77498601])]
# Params passed to generate_synthetic_data: [array([-1.05040374]), array([-1.48818374]), array([-0.68391704]), array([-0.04419421]), array([-1.24364086]), array([-0.84883343]), array([-1.2662759]), array([0.06104454]), array([0.71195811])]
# Current params: [array([-2.30194251]), array([-1.08160421]), array([-0.99178093]), array([-0.71707109]), array([-0.58839018]), array([-0.27868816]), array([-0.09809632]), array([-0.79430142]), array([0.46167848])]
# Proposed params: [array([-2.25027451]), array([-0.96721913]), array([-0.90303546]), array([-0.73475684]), array([-0.53378097]), array([-0.06359306]), array([-0.22294978]), array([-0.7504687]), array([0.63355674])]
# Params passed to generate_synthetic_data: [array([-2.30194251]), array([-1.08160421]), array([-0.99178093]), array([-0.71707109]), array([-0.58839018]), array([-0.27868816]), array([-0.09809632]), array([-0.79430142]), array([0.46167848])]
# Params passed to generate_synthetic_data: [array([-2.25027451]), array([-0.96721913]), array([-0.90303546]), array([-0.73475684]), array([-0.53378097]), array([-0.06359306]), array([-0.22294978]), array([-0.7504687]), array([0.63355674])]
# Current params: [array([-1.05040374]), array([-1.48818374]), array([-0.68391704]), array([-0.04419421]), array([-1.24364086]), array([-0.84883343]), array([-1.2662759]), array([0.06104454]), array([0.71195811])]
# Proposed params: [array([-0.98402284]), array([-1.36987034]), array([-0.65394678]), array([-0.14264971]), array([-1.39951984]), array([-0.98101074]), array([-1.3004529]), array([0.28123153]), array([0.65654482])]
# Params passed to generate_synthetic_data: [array([-1.05040374]), array([-1.48818374]), array([-0.68391704]), array([-0.04419421]), array([-1.24364086]), array([-0.84883343]), array([-1.2662759]), array([0.06104454]), array([0.71195811])]
# Params passed to generate_synthetic_data: [array([-0.98402284]), array([-1.36987034]), array([-0.65394678]), array([-0.14264971]), array([-1.39951984]), array([-0.98101074]), array([-1.3004529]), array([0.28123153]), array([0.65654482])]

# %%
az.plot_trace(trace)
